# %%
From inside a notebook

Click the main branch pill → Git panel → History tab → lists all commits with IDs
Via the Repos UI (Git modal)
In the Workspace sidebar, right-click the repo1 folder → Git... → opens the full Git modal showing branch, commit log, and SHA IDs
